# %%
import json

# %%
with open('data/Stmt_columns.json') as f:
    data = json.load(f)

print(data)
# Out:
# [{'columnname': 'custid', 'description': 'Unique identifier for a customer.'}, {'columnname': 'name', 'description': "Customer's full name."}, {'columnname': 'national', 'description': "Customer's nationality."}, {'columnname': 'resident', 'description': "Customer's residency status (e.g., resident, non-resident)."}, {'columnname': 'industry', 'description': 'Industry in which the customer operates or is employed.'}, {'columnname': 'sector', 'description': 'Sector of the industry the customer belongs to (e.g., finance, technology).'}, {'columnname': 'branch', 'description': "Branch where the customer's account is held."}, {'columnname': 'actype', 'description': 'Type of account (e.g., checking, savings).'}, {'columnname': 'accountno', 'description': "Customer's account number."}, {'columnname': 'ccy', 'description': 'Currency of the account (e.g., USD, EUR).'}, {'columnname': 'category', 'description': 'Customer category (e.g., retail, corporate).'}, {'columnname': 'acbal', 'descript
# ...

# %%
import pandas as pd

# %%
# Load the CSV file into a DataFrame
account_data = pd.read_csv('data/AccountData.csv')

# Find unique values in each column
unique_values = {col: account_data[col].unique() for col in account_data.columns}

print(unique_values)
# Out:
# {'custid': array([444500, 100199,  67038, ..., 182566, 301354, 357989], dtype=int64), 'name': array(['DEEPAK DHAMI', 'UPENDRA P. SUBEDI', 'SIDDHI BHANDARI', ...,
#        'MOTISARA KUMAL', 'SHREE NARAYAN DATTA SIGDEL',
#        'UMESH KUMAR MANDAL'], dtype=object), 'national': array(['NP', ' B', 'US', 'IN', 'AT', 'AU', 'SA', 'JO', ' I', ' D', 'CO',
#        'DE', 'TA', 'S', ' T'], dtype=object), 'resident': array(['NP', 'US', 'IN', 'AT', 'AU', 'SA', 'NO', ' T'], dtype=object), 'industry': array(['9009', '4005', '4000', '9010', '1008', '1004', '4040', '1405',
#        '2005', '9008', '1240', 'NP', '4019', '1413', '4010', '1415',
#        '9000', '9005', '1256', '9021', '4015', '9007', '9030', '4055',
#        '2010', '1230', '4025', '1245', '1006', '1220', '1055', '1235',
#        '1016', '4020', '1002', '1034', '4052', '2430', '1410', '1205',
#        '1018', '1012', '2000', '9020', '2017', '1042', '1050', '1010',
# ...

# %%
account_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Data columns (total 23 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   custid     16383 non-null  int64
#  1   name       16383 non-null  object
#  2   national   16383 non-null  object
#  3   resident   16383 non-null  object
#  4   industry   16383 non-null  object
#  5   sector     16383 non-null  object
#  6   branch     16383 non-null  int64
#  7   actype     16383 non-null  int64
#  8   accountno  16383 non-null  object
#  9   ccy        16383 non-null  object
#  10  category   16383 non-null  object
#  11  acbal      16383 non-null  float64
#  12  lcyacbal   16383 non-null  float64
#  13  mbservice  16383 non-null  bool
#  14  ibservice  16383 non-null  bool
#  15  acservice  16383 non-null  bool
#  16  kyc        16383 non-null  bool
#  17  inactive   16383 non-null  bool
#  18  mobileno   16280 non-null  object
# ...

# %%
account_data.describe(include='all')
# Out:
#                custid               name national resident industry sector  \
# count    16383.000000              16383    16383    16383    16383  16383
# unique            NaN              12988       15        8       52     23
# top               NaN  NEPAL RASTRA BANK       NP       NP     9008   1500
# freq              NaN                 41    16339    16341    14019  15674
# mean    283508.877312                NaN      NaN      NaN      NaN    NaN
# std     224544.989431                NaN      NaN      NaN      NaN    NaN
# min         44.000000                NaN      NaN      NaN      NaN    NaN
# 25%      63772.500000                NaN      NaN      NaN      NaN    NaN
# 50%     242074.000000                NaN      NaN      NaN      NaN    NaN
# 75%     466476.500000                NaN      NaN      NaN      NaN    NaN
# max     999998.000000                NaN      NaN      NaN      NaN    NaN
#
# ...

# %%
from langchain_community.llms import Ollama

# %% [markdown]
# phi4:latest                ac896e5b8b34    9.1 GB    6 days ago
# gemma:2b                   b50d6c999e59    1.7 GB    5 weeks ago
# llama3.2-vision:latest     38107a0cd119    7.9 GB    2 months ago
# qwen2.5-coder:7b           4a26c19c376e    4.7 GB    2 months ago
# granite3-dense:8b          b5e91128f3ef    4.9 GB    2 months ago
# codellama:latest           8fdf8f752f6e    3.8 GB    3 months ago
# minicpm-v:latest           1862d7d5fee5    5.5 GB    3 months ago
# nomic-embed-text:latest    0a109f422b47    274 MB    3 months ago
# llama3.2:latest            a80c4f17acd5    2.0 GB    3 months ago
# gemma2:latest              ff02c3702f32    5.4 GB    3 months ago
# codellama:7b               8fdf8f752f6e    3.8 GB    3 months ago
# llama3.1:latest            42182419e950    4.7 GB    3 months ago

# %%
ollama_llm = Ollama(model='phi4:latest')
